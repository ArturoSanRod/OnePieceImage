# %% [markdown]
# # Instituto Tecnológico y de Estuidos Superiores de Monterrey Campus Querétaro
# ## Arturo Sánchez Rodríguez | A01275427
# # OnePiece

# %%
#Importar las librerías que vamos a utilizar en el proyecto de clasificación de imágenes
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras import models, layers

# %%
onePiece_data = "OnePiece/Data/Data" #Definimos la ruta de nuestro dataset para luego poder llamarlo
print(os.listdir("OnePiece/Data/Data/")[::]) #Vemos las clases que tenemos en nuestro dataset
# Out:
# ['Akainu', '.DS_Store', 'Sanji', 'Jinbei', 'Nami', 'Law', 'Crocodile', 'Mihawk', 'Chopper', 'Zoro', 'Shanks', 'Brook', 'Rayleigh', 'Usopp', 'Kurohige', 'Franky', 'Ace', 'Luffy', 'Robin']

# %% [markdown]
# ## Aqui lo que tenemos que hacer es convertir las imágenes a números para que la computadora las pueda leer

# %%
#A diferencia con el dataset de MNIST que ya tiene las imágenes convertidas en números y listas para ser utilizadas, con nuestro modelo no esta asi entonces como la computadora no puede ver las imágenes tenemos que convertirlos en números.

def cargar_img(path, img_size=(64, 64)):
    images = []
    labels = []

    class_names = sorted([
        clase for clase in os.listdir(path)
        if os.path.isdir(os.path.join(path, clase))
    ])

    for label_index, class_name in enumerate(class_names):
        class_path = os.path.join(path, class_name)
        for file_name in os.listdir(class_path):
            if file_name.lower().endswith((".png", ".jpg", "jpeg")):
                img_path = os.path.join(class_path, file_name)
                img = tf.keras.utils.load_img(img_path, target_size=img_size)
                img_array = tf.keras.utils.img_to_array(img)
                images.append(img_array)
                labels.append(label_index)
    images = np.array(images)
    labels = np.array(labels)

    return images, labels, class_names

images, labels, class_names = cargar_img(onePiece_data)
# Out:
# /Users/arturosr/Library/Python/3.11/lib/python/site-packages/PIL/Image.py:1137: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(

# %% [markdown]
# ## Imprimimos la forma que tienen las imágenes, sus etiquetas, nombre de las clases y la cantidad de clases que tenemos (Las clases son los personajes en el dataset)

# %%
#Imprimimos la forma de las imágenes, etiquetas, nombres de clases y la cantidad de clases para verificar que todo se haya cargado correctamente
print(images.shape)
print(labels.shape)
print(class_names)
print(len(class_names))
# Out:
# (11737, 64, 64, 3)
# (11737,)
# ['Ace', 'Akainu', 'Brook', 'Chopper', 'Crocodile', 'Franky', 'Jinbei', 'Kurohige', 'Law', 'Luffy', 'Mihawk', 'Nami', 'Rayleigh', 'Robin', 'Sanji', 'Shanks', 'Usopp', 'Zoro']
# 18

# %% [markdown]
# ## Separamos el dataset en Test y Train

# %%
#Separamos el dataset en TRAIN y TEST
train_img, test_img, train_labels, test_labels = train_test_split(
    images,
    labels,
    test_size=0.2,
    random_state=42,
    stratify=labels
)

print("Train imágenes:", train_img.shape)
print("Test imágenes:", test_img.shape)
print("Train labels:", train_labels.shape)
print("Test labels:", test_labels.shape)
# Out:
# Train imágenes: (9389, 64, 64, 3)
# Test imágenes: (2348, 64, 64, 3)
# Train labels: (9389,)
# Test labels: (2348,)

# %% [markdown]
# ## Escalamos las imágenes para que los valores sean entre 0 y 1

# %%
def scale_img(train_img, test_img):
    train_img = train_img / 255.
    test_img = test_img / 255.
    return train_img, test_img

# %%
train_img, test_img = scale_img(train_img, test_img)

print("train_img.shape:", train_img.shape)
print("test_img.shape:", test_img.shape)
print("train_img.min():", train_img.min(), "train_img.max():", train_img.max())
print("test_img.min():", test_img.min(), "test_img.max():", test_img.max())
# Out:
# train_img.shape: (9389, 64, 64, 3)
# test_img.shape: (2348, 64, 64, 3)
# train_img.min(): 0.0 train_img.max(): 1.0
# test_img.min(): 0.0 test_img.max(): 1.0

# %% [markdown]
# ## Guardamos las imágenes de test y train en formato .npy para luego pode utilizarlas

# %%
np.save("train_img.npy", train_img)
np.save("test_img.npy", test_img)

np.save("train_labels.npy", train_labels)
np.save("test_labels.npy", test_labels)

print("Se guardaron los test y train en formato .npy de manera correcta!")
# Out:
# Se guardaron los test y train en formato .npy de manera correcta!

# %%
# Visualizar imágenes de ejemplo

import random

plt.figure(figsize=(10,10))

for i in range(9):
    idx = random.randint(0, len(train_img)-1)

    plt.subplot(3,3,i+1)
    plt.imshow(train_img[idx])
    plt.title(class_names[train_labels[idx]])
    plt.axis("off")

plt.show()

# %% [markdown]
# # Modelo 1 MLP

# %%
#Tenemos que definir cuántas clases tiene nuestro dataset

num_classes = len(class_names)
print("Número de clases:", num_classes)
print("Clases:", class_names)
# Out:
# Número de clases: 18
# Clases: ['Ace', 'Akainu', 'Brook', 'Chopper', 'Crocodile', 'Franky', 'Jinbei', 'Kurohige', 'Law', 'Luffy', 'Mihawk', 'Nami', 'Rayleigh', 'Robin', 'Sanji', 'Shanks', 'Usopp', 'Zoro']

# %%
#Creamos el modelo de red neuronal tradicional MLP (Multi-layer Perceptron)

def get_model(input_shape, num_classes):
    model = models.Sequential([
        layers.Flatten(input_shape=input_shape),
        layers.Dense(128, activation="relu"),
        layers.Dense(num_classes, activation="softmax")
    ])
    return model

model = get_model(input_shape=(64, 64, 3), num_classes=num_classes) 
model.summary()
# Out:
# /Users/arturosr/Library/Python/3.11/lib/python/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 12288)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     1,572,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 18)             │         2,322 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,575,314 (6.01 MB)
#  Trainable params: 1,575,314 (6.01 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
#Compiamos el modelo 
def compile_model(model):
    model.compile(
        optimizer="adam", #Adam es el algoritmo que modifica los pesos y los ajusta automáticamente
        loss="sparse_categorical_crossentropy", #Función de pérdida para clasificación multiclase
        metrics=["accuracy"] #Métrica para evaluar el rendimiento del modelo
    )

compile_model(model)

# %%
#Entrenamos el modelo
def train_model(model, train_img, train_labels):
    history = model.fit(train_img, train_labels, validation_split=0.2, epochs=25)
    return history

history = train_model(model, train_img, train_labels)
# Out:
# Epoch 1/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0541 - loss: 3.1331 - val_accuracy: 0.0543 - val_loss: 2.8910
# Epoch 2/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0535 - loss: 2.8912 - val_accuracy: 0.0522 - val_loss: 2.8914
# Epoch 3/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0523 - loss: 2.8902 - val_accuracy: 0.0527 - val_loss: 2.8917
# Epoch 4/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0545 - loss: 2.8888 - val_accuracy: 0.0527 - val_loss: 2.8917
# Epoch 5/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0527 - loss: 2.8877 - val_accuracy: 0.0570 - val_loss: 2.8853
# Epoch 6/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0604 - loss: 2.8816 - val_accuracy: 0.0548 - val_loss: 2.8850
# Epoch 7/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0582 - loss: 2.8797 - val_accuracy: 0.0538 - val_loss: 2.8861
# Epoch 8/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0612 - loss: 2.8785 - val_accuracy: 0.0564 - val_loss: 2.9089
# Epoch 9/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0603 - loss: 2.8768 - val_accuracy: 0.0543 - val_loss: 2.8859
# Epoch 10/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0612 - loss: 2.8757 - val_accuracy: 0.0548 - val_loss: 2.8854
# Epoch 11/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0628 - loss: 2.8752 - val_accuracy: 0.0548 - val_loss: 2.8856
# Epoch 12/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0632 - loss: 2.8743 - val_accuracy: 0.0548 - val_loss: 2.8841
# Epoch 13/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0635 - loss: 2.8749 - val_accuracy: 0.0575 - val_loss: 2.8845
# Epoch 14/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0646 - loss: 2.8738 - val_accuracy: 0.0548 - val_loss: 2.8851
# Epoch 15/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0627 - loss: 2.8739 - val_accuracy: 0.0559 - val_loss: 2.8843
# Epoch 16/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0643 - loss: 2.8709 - val_accuracy: 0.0554 - val_loss: 2.8857
# Epoch 17/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0644 - loss: 2.8700 - val_accuracy: 0.0570 - val_loss: 2.8859
# Epoch 18/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0582 - loss: 2.8687 - val_accuracy: 0.0559 - val_loss: 2.8848
# Epoch 19/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0648 - loss: 2.8679 - val_accuracy: 0.0554 - val_loss: 2.8842
# Epoch 20/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0626 - loss: 2.8687 - val_accuracy: 0.0580 - val_loss: 2.8805
# Epoch 21/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0644 - loss: 2.8661 - val_accuracy: 0.0570 - val_loss: 2.8839
# Epoch 22/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0630 - loss: 2.8669 - val_accuracy: 0.0575 - val_loss: 2.8878
# Epoch 23/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0642 - loss: 2.8658 - val_accuracy: 0.0586 - val_loss: 2.8831
# Epoch 24/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0643 - loss: 2.8650 - val_accuracy: 0.0554 - val_loss: 2.8845
# Epoch 25/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0638 - loss: 2.8638 - val_accuracy: 0.0559 - val_loss: 2.8869

# %%
#Evaluamos el modelo con el set de prueba
test_loss, test_accuracy = model.evaluate(test_img, test_labels)

print("Test loss:", test_loss)
print("Test accuracy:", test_accuracy)
# Out:
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step - accuracy: 0.0605 - loss: 2.8870
# Test loss: 2.8870303630828857
# Test accuracy: 0.06047700345516205

# %% [markdown]
# # Modelo 2 CNN

# %%
#Construimos el modelo CNN

def get_modelo_CNN(input_shape, num_classes):
    model = models.Sequential([
        layers.Conv2D(6, kernel_size=3, padding="same", activation="relu", input_shape=input_shape),
        layers.Flatten(),
        layers.Dense(128, activation="relu"),
        layers.Dense(num_classes, activation="softmax")
    ])
    return model 

model_cnn = get_modelo_CNN(input_shape=(64, 64, 3), num_classes=num_classes)
model_cnn.summary()
# Out:
# /Users/arturosr/Library/Python/3.11/lib/python/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 64, 64, 6)      │           168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 24576)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │     3,145,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 18)             │         2,322 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,148,346 (12.01 MB)
#  Trainable params: 3,148,346 (12.01 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
#Compilamos y entrenamos el modelo CNN

compile_model(model_cnn)
history_cnn = train_model(model_cnn, train_img, train_labels)
# Out:
# Epoch 1/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.0658 - loss: 3.1825 - val_accuracy: 0.0676 - val_loss: 2.8808
# Epoch 2/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.0921 - loss: 2.8325 - val_accuracy: 0.1129 - val_loss: 2.7968
# Epoch 3/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1659 - loss: 2.6385 - val_accuracy: 0.1640 - val_loss: 2.6330
# Epoch 4/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2648 - loss: 2.3497 - val_accuracy: 0.1800 - val_loss: 2.5625
# Epoch 5/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3467 - loss: 2.0918 - val_accuracy: 0.2045 - val_loss: 2.5657
# Epoch 6/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4287 - loss: 1.8287 - val_accuracy: 0.2183 - val_loss: 2.5819
# Epoch 7/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5218 - loss: 1.5485 - val_accuracy: 0.2252 - val_loss: 2.7014
# Epoch 8/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6160 - loss: 1.2760 - val_accuracy: 0.2412 - val_loss: 2.8132
# Epoch 9/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6982 - loss: 1.0298 - val_accuracy: 0.2311 - val_loss: 2.9709
# Epoch 10/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7785 - loss: 0.8010 - val_accuracy: 0.2343 - val_loss: 3.3219
# Epoch 11/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8374 - loss: 0.6100 - val_accuracy: 0.2497 - val_loss: 3.5478
# Epoch 12/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8939 - loss: 0.4529 - val_accuracy: 0.2380 - val_loss: 3.9215
# Epoch 13/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9225 - loss: 0.3377 - val_accuracy: 0.2311 - val_loss: 4.1251
# Epoch 14/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9430 - loss: 0.2515 - val_accuracy: 0.2375 - val_loss: 4.4796
# Epoch 15/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9599 - loss: 0.1882 - val_accuracy: 0.2487 - val_loss: 4.7222
# Epoch 16/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9708 - loss: 0.1436 - val_accuracy: 0.2407 - val_loss: 5.0300
# Epoch 17/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9778 - loss: 0.1111 - val_accuracy: 0.2535 - val_loss: 5.2523
# Epoch 18/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9838 - loss: 0.0858 - val_accuracy: 0.2343 - val_loss: 5.4831
# Epoch 19/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9848 - loss: 0.0730 - val_accuracy: 0.2487 - val_loss: 5.9224
# Epoch 20/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9799 - loss: 0.0882 - val_accuracy: 0.2375 - val_loss: 5.9237
# Epoch 21/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9768 - loss: 0.0933 - val_accuracy: 0.2263 - val_loss: 6.3701
# Epoch 22/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9627 - loss: 0.1338 - val_accuracy: 0.2316 - val_loss: 6.4046
# Epoch 23/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9772 - loss: 0.0893 - val_accuracy: 0.2444 - val_loss: 6.5824
# Epoch 24/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9883 - loss: 0.0459 - val_accuracy: 0.2449 - val_loss: 6.7597
# Epoch 25/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9880 - loss: 0.0444 - val_accuracy: 0.2439 - val_loss: 6.9291

# %%
#Evaluamos el modelo CNN con el set de prueba

test_loss_cnn, test_accuracy_cnn = model_cnn.evaluate(test_img, test_labels)
print("Test loss CNN:", test_loss_cnn)
print("Test accuracy CNN:", test_accuracy_cnn)
# Out:
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2368 - loss: 7.0109
# Test loss CNN: 7.010927677154541
# Test accuracy CNN: 0.2367972731590271

# %% [markdown]
# # Modelo 3
# ## CNN + Data Augmentation

# %%
#implementamos data augmentation para mejorar el rendimiento del modelo 2 CNN y evitar overfitting

data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.15),
    layers.RandomZoom(0.15),
    #layers.RandomTranslation(0.1, 0.1),
    #layers.RandomContrast(0.1),
    #layers.RandomFlip("vertical")
])

# %%
#Contruimos el modelo 3 (CNN) con data augmentation

def get_modelo_CNN_aug(input_shape, num_classes):
    model = models.Sequential([
        layers.Input(shape=input_shape),
        data_augmentation,
        layers.Conv2D(6, kernel_size=3, padding="same", activation="relu"),
        layers.Flatten(),
        layers.Dense(128, activation="relu"),
        layers.Dense(num_classes, activation="softmax")
    ])
    return model 

model_cnn_aug = get_modelo_CNN_aug(input_shape=(64, 64, 3), num_classes=num_classes)
model_cnn_aug.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential_2 (Sequential)       │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 6)      │           168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 24576)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │     3,145,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 18)             │         2,322 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,148,346 (12.01 MB)
#  Trainable params: 3,148,346 (12.01 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
#Compilamos y entrenamos el modelo CNN con data augmentation

compile_model(model_cnn_aug)
history_cnn_aug = train_model(model_cnn_aug, train_img, train_labels)
# Out:
# Epoch 1/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.0819 - loss: 2.9143 - val_accuracy: 0.0905 - val_loss: 2.8272
# Epoch 2/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.1216 - loss: 2.7704 - val_accuracy: 0.1411 - val_loss: 2.6990
# Epoch 3/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.1719 - loss: 2.6194 - val_accuracy: 0.1363 - val_loss: 2.7649
# Epoch 4/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.1980 - loss: 2.5429 - val_accuracy: 0.1709 - val_loss: 2.7001
# Epoch 5/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2141 - loss: 2.4983 - val_accuracy: 0.1768 - val_loss: 2.6250
# Epoch 6/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2253 - loss: 2.4511 - val_accuracy: 0.1986 - val_loss: 2.6321
# Epoch 7/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.2382 - loss: 2.4224 - val_accuracy: 0.2103 - val_loss: 2.5545
# Epoch 8/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.2523 - loss: 2.3917 - val_accuracy: 0.2098 - val_loss: 2.6234
# Epoch 9/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.2590 - loss: 2.3707 - val_accuracy: 0.2178 - val_loss: 2.6059
# Epoch 10/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.2772 - loss: 2.3320 - val_accuracy: 0.2231 - val_loss: 2.6039
# Epoch 11/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2832 - loss: 2.3112 - val_accuracy: 0.2354 - val_loss: 2.6069
# Epoch 12/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2812 - loss: 2.3017 - val_accuracy: 0.2204 - val_loss: 2.6596
# Epoch 13/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2869 - loss: 2.2817 - val_accuracy: 0.2593 - val_loss: 2.5289
# Epoch 14/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2941 - loss: 2.2695 - val_accuracy: 0.2449 - val_loss: 2.4717
# Epoch 15/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2948 - loss: 2.2630 - val_accuracy: 0.2423 - val_loss: 2.5103
# Epoch 16/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2916 - loss: 2.2525 - val_accuracy: 0.2561 - val_loss: 2.4572
# Epoch 17/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.2996 - loss: 2.2369 - val_accuracy: 0.2545 - val_loss: 2.5001
# Epoch 18/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.3149 - loss: 2.2116 - val_accuracy: 0.2460 - val_loss: 2.5238
# Epoch 19/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.3091 - loss: 2.2263 - val_accuracy: 0.2492 - val_loss: 2.5280
# Epoch 20/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.3103 - loss: 2.2053 - val_accuracy: 0.2529 - val_loss: 2.4161
# Epoch 21/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.3142 - loss: 2.2038 - val_accuracy: 0.2742 - val_loss: 2.4169
# Epoch 22/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.3177 - loss: 2.1933 - val_accuracy: 0.2700 - val_loss: 2.5057
# Epoch 23/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.3217 - loss: 2.1739 - val_accuracy: 0.2614 - val_loss: 2.4759
# Epoch 24/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.3254 - loss: 2.1581 - val_accuracy: 0.2444 - val_loss: 2.5234
# Epoch 25/25
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.3169 - loss: 2.1746 - val_accuracy: 0.2614 - val_loss: 2.4612

# %%
# Evaluamos el modelo CNN con data augmentation con el set de prueba

test_loss_cnn_aug, test_accuracy_cnn_aug = model_cnn_aug.evaluate(test_img, test_labels)
print("Test loss CNN con data augmentation:", test_loss_cnn_aug)
print("Test accuracy CNN con data augmentation:", test_accuracy_cnn_aug)
# Out:
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2807 - loss: 2.4711
# Test loss CNN con data augmentation: 2.471073627471924
# Test accuracy CNN con data augmentation: 0.2806643843650818

# %%
# Ver accuracy final de los 3 modelos

#MLP
print(history.history["accuracy"][-1])
print(history.history["val_accuracy"][-1])

#CNN
print(history_cnn.history["accuracy"][-1])
print(history_cnn.history["val_accuracy"][-1])

#CNN con data augmentation
print(history_cnn_aug.history["accuracy"][-1])
print(history_cnn_aug.history["val_accuracy"][-1])
# Out:
# 0.06377313286066055
# 0.055910542607307434
# 0.9880175590515137
# 0.24387645721435547
# 0.3168686032295227
# 0.26144835352897644
